# %%
import pandas as pd

file_path = r"C:\Users\\Asus\\Desktop\\Scraper\\Scraper\\output\\25.22.04_MX_videos.csv"

data = pd.read_csv(file_path)

data.head()
# Out:
#       video_id                                              title  \
# 0  FWDHGyy4IxM                            VAMOS A LA CASA DE BETA
# 1  HoS7mffQ2YQ                                  skibidi toilet 78
# 2  4-SSmIMCCf0                YA ME CANSÉ DE SER TU MEJOR AMIGA 😡
# 3  ELJIbm95p_c  Muere el papa Francisco: el ambivalente papado...
# 4  myPFzhQEghE  LISA - Rapunzel (Kiki Solo Version) (Live Perf...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2025-04-21T02:09:00Z  UCoQm-PeHC-cbJclKJYJ8LzA   Fede Vigevani          24
# 1  2025-04-21T04:00:10Z  UCsSsgPaZ2GSmO6il8Cb5iGA    DaFuq!?Boom!          24
# 2  2025-04-21T22:45:00Z  UCW3bX8K5LuQHw8cKc3U8iUg          Rivers          20
# 3  2025-04-21T09:01:29Z  UCUBIrDsIVzRpKsClMlSlTpQ  BBC News Mundo          25
# 4  2025-04-22T02:00:03Z  UC6-BgjsBa5R3PZQ_kZ8hKPg  LLOUD Official          10
#
#   trending_date                                               tags  \
# ...

# %%
category_mapping = {
    1: "Film & Animation",
    2: "Autos & Vehicles",
    10: "Music",
    15: "Pets & Animals",
    17: "Sports",
    19: "Travel & Events",
    20: "Gaming",
    22: "People & Blogs",
    23: "Comedy",
    24: "Entertainment",
    25: "News & Politics",
    26: "Howto & Style",
    27: "Education",
    28: "Science & Technology",
    29: "Nonprofits & Activism",
    18: "Short Movies",
    21: "Videoblogging",
    30: "Movies",
    31: "Anime/Animation",
    32: "Action/Adventure",
    33: "Classics",
    34: "Comedy",
    35: "Documentary",
    36: "Drama",
    37: "Family",
    38: "Foreign",
    39: "Horror",
    40: "Sci-Fi/Fantasy",
    41: "Thriller",
    42: "Shorts",
    43: "Shows",
    44: "Trailers"
}

data['category_title'] = data['categoryId'].map(category_mapping)

data.head()
# Out:
#       video_id                                              title  \
# 0  FWDHGyy4IxM                            VAMOS A LA CASA DE BETA
# 1  HoS7mffQ2YQ                                  skibidi toilet 78
# 2  4-SSmIMCCf0                YA ME CANSÉ DE SER TU MEJOR AMIGA 😡
# 3  ELJIbm95p_c  Muere el papa Francisco: el ambivalente papado...
# 4  myPFzhQEghE  LISA - Rapunzel (Kiki Solo Version) (Live Perf...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2025-04-21T02:09:00Z  UCoQm-PeHC-cbJclKJYJ8LzA   Fede Vigevani          24
# 1  2025-04-21T04:00:10Z  UCsSsgPaZ2GSmO6il8Cb5iGA    DaFuq!?Boom!          24
# 2  2025-04-21T22:45:00Z  UCW3bX8K5LuQHw8cKc3U8iUg          Rivers          20
# 3  2025-04-21T09:01:29Z  UCUBIrDsIVzRpKsClMlSlTpQ  BBC News Mundo          25
# 4  2025-04-22T02:00:03Z  UC6-BgjsBa5R3PZQ_kZ8hKPg  LLOUD Official          10
#
#   trending_date                                               tags  \
# ...

# %%
data['category_title'].isnull().sum()
# Out:
# 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
category_counts = data['category_title'].value_counts()

top_categories = category_counts.head(3)

plt.figure(figsize=(10, 6))
top_categories.plot(kind='bar', color='skyblue')
plt.title('Top 3 YouTube Categories in Mexico')
plt.xlabel('Category')
plt.ylabel('Number of Videos')
plt.xticks(rotation=45)
plt.show()
